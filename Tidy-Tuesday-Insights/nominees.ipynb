# %% [markdown]
# 2021-09-21 <br/>
# Emmy Awards	<br/>
# https://github.com/rfordatascience/tidytuesday/blob/master/data/2021/2021-09-21/readme.md

# %% [markdown]
# Basic Pice Chart - Completed <br/>
# Sunburst Chart - Completed

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'notebook'

# %%
df=pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-09-21/nominees.csv')

# %%
df.head()
# Out:
#                                             category  \
# 0  Outstanding Character Voice-Over Performance -...
# 1  Outstanding Character Voice-Over Performance -...
# 2  Outstanding Character Voice-Over Performance -...
# 3  Outstanding Character Voice-Over Performance -...
# 4  Outstanding Production Design For A Narrative ...
#
#                                                 logo  \
# 0  https://www.emmys.com/sites/default/files/styl...
# 1  https://www.emmys.com/sites/default/files/styl...
# 2  https://www.emmys.com/sites/default/files/styl...
# 3  https://www.emmys.com/sites/default/files/styl...
# 4  https://www.emmys.com/sites/default/files/styl...
#
#                                 production     type  \
# 0                                      NaN  Nominee
# 1                                      NaN  Nominee
# 2                                      NaN  Nominee
# 3                                      NaN  Nominee
# 4  Elisabeth Williams, Production Designer  Nominee
#
# ...

# %%
df.shape
# Out:
# (29678, 10)

# %%
df.distributor.value_counts()
# Out:
# HBO              4442
# NBC              3623
# CBS              2963
# ABC              2945
# Netflix          2144
#                  ...
# VEVO.com            1
# GMC                 1
# Yahoo               1
# Freeform            1
# drmartens.com       1
# Name: distributor, Length: 199, dtype: int64

# %%
df_top_distributors=df.groupby(['distributor','type'])['category'].count().reset_index().sort_values(by='category',ascending=False)[:5].distributor.tolist()

# %%
df_top_distributors
# Out:
# ['HBO', 'NBC', 'CBS', 'ABC', 'Netflix']

# %%
df_top_map=df.isin({'distributor':df_top_distributors})

# %%
df_top_map
# Out:
#        category   logo  production   type  title  distributor  producer  \
# 0         False  False       False  False  False         True     False
# 1         False  False       False  False  False         True     False
# 2         False  False       False  False  False        False     False
# 3         False  False       False  False  False        False     False
# 4         False  False       False  False  False        False     False
# ...         ...    ...         ...    ...    ...          ...       ...
# 29673     False  False       False  False  False         True     False
# 29674     False  False       False  False  False         True     False
# 29675     False  False       False  False  False         True     False
# 29676     False  False       False  False  False         True     False
# 29677     False  False       False  False  False         True     False
#
#         year   page  page_id
# 0      False  False    False
# 1      False  False    False
# ...

# %%
df_top=df.loc[df_top_map.distributor]

# %%
df_top
# Out:
#                                                 category  \
# 0      Outstanding Character Voice-Over Performance -...
# 1      Outstanding Character Voice-Over Performance -...
# 8      Outstanding Production Design For A Narrative ...
# 9      Outstanding Production Design For A Narrative ...
# 10     Outstanding Production Design For A Narrative ...
# ...                                                  ...
# 29673   BEST CONTINUING PERFORMANCE BY AN ACTRESS - 1957
# 29674   BEST CONTINUING PERFORMANCE BY AN ACTRESS - 1957
# 29675   BEST CONTINUING PERFORMANCE BY AN ACTRESS - 1957
# 29676   BEST CONTINUING PERFORMANCE BY AN ACTRESS - 1957
# 29677   BEST CONTINUING PERFORMANCE BY AN ACTRESS - 1957
#
#                                                     logo  \
# 0      https://www.emmys.com/sites/default/files/styl...
# 1      https://www.emmys.com/sites/default/files/styl...
# 8      https://www.emmys.com/sites/default/files/styl...
# ...

# %%
df_top_nomination=df_top.groupby(['distributor','type'])['category'].count().reset_index()

# %%
df_top_nomination
# Out:
#   distributor     type  category
# 0         ABC  Nominee      2502
# 1         ABC   Winner       443
# 2         CBS  Nominee      2519
# 3         CBS   Winner       444
# 4         HBO  Nominee      3125
# 5         HBO   Winner      1317
# 6         NBC  Nominee      2933
# 7         NBC   Winner       690
# 8     Netflix  Nominee      1751
# 9     Netflix   Winner       393

# %%
df_total_nomination=df_top.groupby(['distributor'])['category'].count().reset_index()

# %%
df_total_nomination
# Out:
#   distributor  category
# 0         ABC      2945
# 1         CBS      2963
# 2         HBO      4442
# 3         NBC      3623
# 4     Netflix      2144

# %%
import plotly.express as px
fig = px.pie(df_total_nomination, values='category', names='distributor', title='Total nominations among the top 5 Distributors')
fig.show()
# Out:
# <div>                            <div id="a0067bca-aeae-4c6c-a487-a8f55e506cf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0067bca-aeae-4c6c-a487-a8f55e506cf4")) {                    Plotly.newPlot(                        "a0067bca-aeae-4c6c-a487-a8f55e506cf4",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "distributor=%{label}<br>category=%{value}<extra></extra>", "labels": ["ABC", "CBS", "HBO", "NBC", "Netflix"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [2945, 2963, 4442, 3623, 2144]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": 
# ...

# %%
# Display Output in production
img_bytes = fig.to_image(format="png")
from IPython.display import Image
Image(img_bytes)

# %%
df_top_nomination[df_top_nomination['type']=='Winner']
# Out:
#   distributor    type  category
# 1         ABC  Winner       443
# 3         CBS  Winner       444
# 5         HBO  Winner      1317
# 7         NBC  Winner       690
# 9     Netflix  Winner       393

# %%
fig = px.pie(df_top_nomination[df_top_nomination['type']=='Winner'], values='category', names='distributor', title='Total Winners among the top 5 Distributors')
fig.show()
# Out:
# <div>                            <div id="bbaa7194-dd49-4018-b74d-15c5d16e9f4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbaa7194-dd49-4018-b74d-15c5d16e9f4c")) {                    Plotly.newPlot(                        "bbaa7194-dd49-4018-b74d-15c5d16e9f4c",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "distributor=%{label}<br>category=%{value}<extra></extra>", "labels": ["ABC", "CBS", "HBO", "NBC", "Netflix"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [443, 444, 1317, 690, 393]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5
# ...

# %%
# Display Output in production
img_bytes = fig.to_image(format="png")
from IPython.display import Image
Image(img_bytes)

# %%
df_top_nomination.head()
# Out:
#   distributor     type  category
# 0         ABC  Nominee      2502
# 1         ABC   Winner       443
# 2         CBS  Nominee      2519
# 3         CBS   Winner       444
# 4         HBO  Nominee      3125

# %%
df_top_nomination.type.tolist()
# Out:
# ['Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner']

# %%
# Representing both through a sunburst chart 

import plotly.express as px
df = px.data.tips()
fig = px.sunburst(df_top_nomination, path=['distributor','type'], values='category',title='Aggregated breakdown of the top 5 Distributors')
fig.show()
# Out:
# <div>                            <div id="ac0e9ed1-5f36-4780-a189-de91ff77ef88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac0e9ed1-5f36-4780-a189-de91ff77ef88")) {                    Plotly.newPlot(                        "ac0e9ed1-5f36-4780-a189-de91ff77ef88",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>category=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["ABC/Nominee", "CBS/Nominee", "HBO/Nominee", "NBC/Nominee", "Netflix/Nominee", "ABC/Winner", "CBS/Winner", "HBO/Winner", "NBC/Winner", "Netflix/Winner", "ABC", "CBS", "HBO", "NBC", "Netflix"], "labels": ["Nominee", "Nominee", "Nominee", "Nominee", "Nominee", "Winner", "Winner", "Win
# ...

# %%
# Display Output in production
img_bytes = fig.to_image(format="png")
from IPython.display import Image
Image(img_bytes)
