# %% [markdown]
# 2021-10-12	<br/>
# Global Seafood <br/>
# https://github.com/rfordatascience/tidytuesday/blob/master/data/2021/2021-10-12/readme.md

# %% [markdown]
# Wide-format bar plot - Completed <br/>
# Faceted plots - Completed

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
pio.renderers.default='notebook'
import os

# %%
df =pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-10-12/global-fishery-catch-by-sector.csv')

# %%
df.head()
# Out:
#   Entity      Code  Year  Artisanal (small-scale commercial)  Discards  \
# 0  World  OWID_WRL  1950                             7526795   5874170
# 1  World  OWID_WRL  1951                             8278304   6278225
# 2  World  OWID_WRL  1952                             8272109   7230311
# 3  World  OWID_WRL  1953                             8469284   7172937
# 4  World  OWID_WRL  1954                             9226926   8012930
#
#    Industrial (large-scale commercial)  Recreational  Subsistence
# 0                             14566338        268260      2677833
# 1                             15417937        284319      2704471
# 2                             16463942        293558      2728141
# 3                             17163789        292070      2753098
# 4                             18340199        304398      2895153

# %%
df_10=df.tail(10)

# %%
wide_df = px.data.medals_wide()

fig = px.bar(wide_df, x="nation", y=["gold", "silver", "bronze"], title="Wide-Form Input")
fig.show()
# Out:
# <div>                            <div id="8669fe52-8161-4945-b31e-6710d6cf40a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8669fe52-8161-4945-b31e-6710d6cf40a8")) {                    Plotly.newPlot(                        "8669fe52-8161-4945-b31e-6710d6cf40a8",                        [{"alignmentgroup": "True", "hovertemplate": "variable=gold<br>nation=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "gold", "marker": {"color": "#636efa"}, "name": "gold", "offsetgroup": "gold", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["South Korea", "China", "Canada"], "xaxis": "x", "y": [24, 10, 9], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=silver<br>nation=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "silver", "marker": {"color": "#EF553B"}, "name": "silver", "offsetgroup": "silver", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["South Korea", "China", "Canada"], "xaxis": "x", "y": [13, 15, 12], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=bronze<br>nation=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "bronze", "marker": {"color": "#00cc96"}, "name": "bronze", "offsetgroup": "bronze", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["South Korea", "China", "Canada"], "xaxis": "x", "y": [11, 8, 12], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.444444444 ...

# %%
# Display Output in production
img_bytes = fig.to_image(format="png")
from IPython.display import Image
Image(img_bytes)

# %%
communities=df_10.columns[3:]

# %%
df_10
# Out:
#    Entity      Code  Year  Artisanal (small-scale commercial)  Discards  \
# 51  World  OWID_WRL  2001                            20046446  11506452
# 52  World  OWID_WRL  2002                            19742034  10791660
# 53  World  OWID_WRL  2003                            20568530  10782853
# 54  World  OWID_WRL  2004                            21076208  10387939
# 55  World  OWID_WRL  2005                            20966689  10014530
# 56  World  OWID_WRL  2006                            21417851   9530758
# 57  World  OWID_WRL  2007                            21097388   9725492
# 58  World  OWID_WRL  2008                            21111836   9568906
# 59  World  OWID_WRL  2009                            21828623   9369530
# 60  World  OWID_WRL  2010                            21586606   9638888
#
#     Industrial (large-scale commercial)  Recreational  Subsistence
# 51                             84201719        769491      3955601
# 52                             84367375        758863      3879482
# 53                             80954017        771767      3865552
# 54                             85760977        771531      3808617
# 55                             83779026        745431      3718690
# 56                             78480816        790270      3792749
# 57                             78861788        804477      3623797
# 58                             76840638        826843      3629819
# 59                             75728150        805632      3630156
# 60                             73326274        808357      3627383

# %%
cols=['Artisanal (small-scale commercial)','Discards','Industrial (large-scale commercial)','Recreational','Subsistence']

# %%
 # ['stack', 'group', 'overlay', 'relative']
#communities = ['Artisanal (small-scale commercial)','Discards','Industrial (large-scale commercial)	Recreationa','Subsistence'] # or df_users_community.columns[3:]

fig = px.bar(df_10, x='Year', y= cols, facet_col='Year',  facet_col_wrap=5, barmode='group', 
             title='A decade of fishing')
fig.show()
# Out:
# <div>                            <div id="9922952e-386f-40a4-b777-1184695873d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9922952e-386f-40a4-b777-1184695873d8")) {                    Plotly.newPlot(                        "9922952e-386f-40a4-b777-1184695873d8",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2001], "xaxis": "x6", "y": [20046446], "yaxis": "y6"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2002], "xaxis": "x7", "y": [19742034], "yaxis": "y7"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2003], "xaxis": "x8", "y": [20568530], "yaxis": "y8"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2004], "xaxis": "x9", "y": [21076208], "yaxis": "y9"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2005], "xaxis": "x10", "y": [20966689], "yaxis": "y10"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2006], "xaxis": "x", "y": [21417851], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)", "offsetgroup": "Artisanal (small-scale commercial)", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2007], "xaxis": "x2", "y": [21097388], "yaxis": "y2"}, {"alignmentgroup": "True", "hovertemplate": "variable=Artisanal (small-scale commercial)<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Artisanal (small-scale commercial)", "marker": {"color": "#636efa"}, "name": "Artisanal (small-scale commercial)",  ...

# %%
# Display Output in production
img_bytes = fig.to_image(format="png")
from IPython.display import Image
Image(img_bytes)
