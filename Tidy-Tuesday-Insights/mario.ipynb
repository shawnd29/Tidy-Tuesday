# %% [markdown]
# Race-Bar Chart: Completed

# %% [markdown]
# 2021-05-25 <br/>
# Mario Kart World Records <br/>
# https://github.com/rfordatascience/tidytuesday/blob/master/data/2021/2021-05-25/readme.md

# %% [markdown]
# ### Learning Links
#
# https://towardsdatascience.com/creating-bar-chart-race-animation-with-python-cdb01144074e

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-05-25/records.csv')

# %%
df.head()
# Out:
#            track       type shortcut   player system_played        date  \
# 0  Luigi Raceway  Three Lap       No    Salam          NTSC  1997-02-15
# 1  Luigi Raceway  Three Lap       No    Booth          NTSC  1997-02-16
# 2  Luigi Raceway  Three Lap       No    Salam          NTSC  1997-02-16
# 3  Luigi Raceway  Three Lap       No    Salam          NTSC  1997-02-28
# 4  Luigi Raceway  Three Lap       No  Gregg G          NTSC  1997-03-07
#
#   time_period    time  record_duration
# 0   2M 12.99S  132.99                1
# 1    2M 9.99S  129.99                0
# 2    2M 8.99S  128.99               12
# 3    2M 6.99S  126.99                7
# 4    2M 4.51S  124.51               54

# %%
# Skipping Cleaning

# %%
df['date']= pd.to_datetime(df['date']) 
df.groupby([df['date'].dt.year, df['date'].dt.month,df['player']]).agg({'time':min}).unstack()
# Out:
#             time                                                               \
# player       ABE Alex G Allen C Ben M   Booth    Dan Daniel L David B David K
# date date
# 1997 2       NaN    NaN     NaN   NaN  129.99    NaN      NaN     NaN     NaN
#      3       NaN    NaN     NaN   NaN     NaN    NaN      NaN     NaN     NaN
#      4       NaN    NaN     NaN   NaN   37.33    NaN      NaN     NaN     NaN
#      5       NaN    NaN     NaN   NaN   61.54    NaN      NaN     NaN     NaN
#      6     99.79    NaN     NaN   NaN     NaN    NaN      NaN     NaN     NaN
# ...          ...    ...     ...   ...     ...    ...      ...     ...     ...
# 2020 10      NaN    NaN     NaN   NaN     NaN  30.78      NaN     NaN     NaN
#      11      NaN    NaN     NaN   NaN     NaN  38.96      NaN     NaN     NaN
#      12      NaN    NaN     NaN   NaN     NaN    NaN      NaN     NaN     NaN
# 2021 1       NaN    NaN     NaN   NaN     NaN  27.62      NaN     NaN     NaN
#      2       NaN    NaN     NaN   NaN     NaN  37.73      NaN     NaN     NaN
#
#                    ...                                                      \
# player    Eddie T  ... Tim E Troy Trystan    VAJ Weatherton    Wonn  Zoran
# date date          ...
# 1997 2        NaN  ...   NaN  NaN     NaN    NaN        NaN     NaN    NaN
#      3        NaN  ...   NaN  NaN     NaN    NaN        NaN  130.34    NaN
#      4        NaN  ...   NaN  NaN     NaN    NaN        NaN   88.21    NaN
#      5        NaN  ...   NaN  NaN     NaN    NaN        NaN     NaN    NaN
#      6        NaN  ...   NaN  NaN     NaN    NaN        NaN   89.60    NaN
# ...           ...  ...   ...  ...     ...    ...        ...     ...    ...
# 2020 10       NaN  ...   NaN  NaN     NaN    NaN        NaN     NaN  54.13
#      11       NaN  ...   NaN  NaN     NaN    NaN        NaN     NaN    NaN
#      12       NaN  ...   NaN  NaN     NaN  23.77        NaN     NaN    NaN
# 2021 1        NaN  ...   NaN  NaN     NaN  23.65        NaN     NaN    NaN
#      2        NaN  ...   NaN  NaN     NaN    NaN      54.67     NaN    NaN
#
#
# player    Zwartjes abney317 iMathII
# date date
# 1997 2         NaN      NaN     NaN
#      3         NaN      NaN     NaN
#      4         NaN      NaN     NaN
#      5         NaN      NaN     NaN
#      6         NaN      NaN     NaN
# ...            ...      ...     ...
# 2020 10        NaN    50.39     NaN
#      11        NaN    91.65     NaN
#      12        NaN    23.71     NaN
# 2021 1         NaN    23.61     NaN
#      2         NaN    17.29   30.31
#
# [242 rows x 65 columns]

# %%
a=df.groupby([df['date'].dt.year,'player'])['time'].min().unstack()

# %%
a.head()
# Out:
# player    ABE  Alex G  Allen C  Ben M   Booth  Dan  Daniel L  David B  \
# date
# 1997    99.79     NaN    28.22    NaN   28.29  NaN       NaN    110.7
# 1998      NaN     NaN      NaN    NaN   27.11  NaN       NaN      NaN
# 1999      NaN     NaN      NaN  28.65   28.82  NaN       NaN      NaN
# 2000      NaN     NaN      NaN  28.49  111.08  NaN       NaN      NaN
# 2001      NaN     NaN      NaN  26.36  110.69  NaN       NaN      NaN
#
# player  David K  Eddie T  ...  Tim E  Troy  Trystan  VAJ  Weatherton   Wonn  \
# date                      ...
# 1997     109.02      NaN  ...    NaN   NaN      NaN  NaN         NaN  22.89
# 1998        NaN      NaN  ...    NaN   NaN      NaN  NaN         NaN  27.67
# 1999        NaN      NaN  ...    NaN   NaN      NaN  NaN         NaN    NaN
# 2000        NaN      NaN  ...    NaN   NaN      NaN  NaN         NaN    NaN
# 2001        NaN      NaN  ...    NaN   NaN      NaN  NaN         NaN    NaN
#
# player  Zoran  Zwartjes  abney317  iMathII
# date
# 1997      NaN     63.86       NaN      NaN
# 1998      NaN     33.39       NaN      NaN
# 1999      NaN     31.37       NaN      NaN
# 2000      NaN     27.91       NaN      NaN
# 2001      NaN    126.06       NaN      NaN
#
# [5 rows x 65 columns]

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(df=a, filename='a2.mp4')
# Out:
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %%
bcr.bar_chart_race(df = a, 
                   n_bars = 6, 
                   sort='asc',
                   title='Premier League Clubs Points Since 1992',
                   filename = 'pl_clubs.mp4')
# Out:
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
#   warnings.warn("Some of your columns never make an appearance in the animation. "

# %%
def bar_race(df, title):

    bcr.bar_chart_race(
        df=a,
        filename=title+'.mp4',
        orientation='h',
        sort='asc',
        n_bars=6,
        fixed_order=False,
        fixed_max=False,
        steps_per_period=1,
        period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
        period_fmt= None,
        # period_summary_func=lambda v, r: {'x': .99, 'y': .18,
        #                                   's': f'Fastest times: {v.nsmallest(6).min():,.0f}',
        #                                   'ha': 'right', 'size': 8, 'family': 'Courier New'},
        perpendicular_bar_func='median',
        period_length=800,
        figsize=(5, 8),
        dpi=144,
        cmap='dark12',
        title=title,
        title_size='',
        bar_label_size=7,
        tick_label_size=7,
        shared_fontdict={'family' : 'Helvetica', 'color' : '.1'},
        scale='linear',
        writer='ffmpeg',
        fig=None,
        bar_kwargs={'alpha': .7},
        filter_column_colors=True)  
    pass

# %%
bar_race(a,'Fastest time by player (Any Type)')
# Out:
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
#   warnings.warn("Some of your columns never make an appearance in the animation. "

# %%
b= df[df["type"]=="Three Lap"].groupby(['date','player'])['time'].min().unstack()

# %%
bar_race(b,'Fastest time by player (Three Laps)')
# Out:
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %%
c= df[df["type"]=="One Lap"].groupby(['date','player'])['time'].min().unstack()

# %%
bar_race(c,'Fastest time by player (One Lap)')
# Out:
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0, flags=flags)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %% [markdown]
# ## This displays a race Bar chart of the top speed-runners over time.
