# %% [markdown]
# 2021-07-13 <br/>
# Scooby Doo <br/>
# https://github.com/rfordatascience/tidytuesday/blob/master/data/2021/2021-07-13/readme.md

# %% [markdown]
# Multi-plots: Completed <br/>
# Word Cloud: Unfinished

# %% [markdown]
# https://stackoverflow.com/questions/43606339/generate-word-cloud-from-single-column-pandas-dataframe  <br/>
# https://towardsdatascience.com/create-word-cloud-into-any-shape-you-want-using-python-d0b88834bc32 <br/>
# https://medium.com/analytics-vidhya/data-visualization-word-clouds-with-python-fbb6395be18f <br/>
# https://www.python-graph-gallery.com/125-small-multiples-for-line-chart

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("darkgrid")

# %%
df=pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-07-13/scoobydoo.csv')
df["date_aired"] = pd.to_datetime(df["date_aired"])

# %%
df.head()
# Out:
#    index                 series_name network season  \
# 0      1  Scooby Doo, Where Are You!     CBS      1
# 1      2  Scooby Doo, Where Are You!     CBS      1
# 2      3  Scooby Doo, Where Are You!     CBS      1
# 3      4  Scooby Doo, Where Are You!     CBS      1
# 4      5  Scooby Doo, Where Are You!     CBS      1
#
#                        title  imdb  engagement date_aired  run_time  \
# 0  What a Night for a Knight   8.1       556.0 1969-09-13        21
# 1      A Clue for Scooby Doo   8.1       479.0 1969-09-20        22
# 2       Hassle in the Castle   8.0       455.0 1969-09-27        21
# 3     Mine Your Own Business   7.8       426.0 1969-10-04        21
# 4      Decoy for a Dognapper   7.5       391.0 1969-10-11        21
#
#       format  ... batman scooby_dum scrappy_doo hex_girls blue_falcon  \
# 0  TV Series  ...  False      False       False     False       False
# 1  TV Series  ...  False      False       False     False       False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     603 non-null    int64
#  1   series_name               603 non-null    object
#  2   network                   603 non-null    object
#  3   season                    603 non-null    object
#  4   title                     603 non-null    object
#  5   imdb                      588 non-null    float64
#  6   engagement                588 non-null    float64
#  7   date_aired                603 non-null    object
#  8   run_time                  603 non-null    int64
#  9   format                    603 non-null    object
#  10  monster_name              516 non-null    object
#  11  monster_gender            516 non-null    object
#  12  monster_type              516 non-null    object
# ...

# %%
df.describe()
# Out:
#             index        imdb     engagement    run_time  monster_amount  \
# count  603.000000  588.000000     588.000000  603.000000      603.000000
# mean   302.000000    7.277891     580.329932   23.520730        1.749585
# std    174.215384    0.732493    4807.924225   17.207571        2.289361
# min      1.000000    4.200000       7.000000    4.000000        0.000000
# 25%    151.500000    6.900000      27.000000   12.000000        1.000000
# 50%    302.000000    7.300000      54.500000   22.000000        1.000000
# 75%    452.500000    7.700000     128.250000   23.000000        2.000000
# max    603.000000    9.600000  100951.000000   94.000000       19.000000
#
#        suspects_amount  culprit_amount    split_up  another_mystery  \
# count       603.000000      603.000000  384.000000       384.000000
# mean          2.850746        1.039801    0.335938         0.177083
# std           2.616891        1.066747    0.549541         0.414988
# ...

# %%
df.columns
# Out:
# Index(['index', 'series_name', 'network', 'season', 'title', 'imdb',
#        'engagement', 'date_aired', 'run_time', 'format', 'monster_name',
#        'monster_gender', 'monster_type', 'monster_subtype', 'monster_species',
#        'monster_real', 'monster_amount', 'caught_fred', 'caught_daphnie',
#        'caught_velma', 'caught_shaggy', 'caught_scooby', 'captured_fred',
#        'captured_daphnie', 'captured_velma', 'captured_shaggy',
#        'captured_scooby', 'unmask_fred', 'unmask_daphnie', 'unmask_velma',
#        'unmask_shaggy', 'unmask_scooby', 'snack_fred', 'snack_daphnie',
#        'snack_velma', 'snack_shaggy', 'snack_scooby', 'unmask_other',
#        'caught_other', 'caught_not', 'trap_work_first', 'setting_terrain',
#        'setting_country_state', 'suspects_amount', 'non_suspect', 'arrested',
#        'culprit_name', 'culprit_gender', 'culprit_amount', 'motive',
#        'if_it_wasnt_for', 'and_that', 'door_gag', 'number_of_snacks',
# ...

# %%
a=df.groupby(df.date_aired.dt.year)['imdb'].mean().reset_index()

# %%
a.head()
# Out:
#    date_aired      imdb
# 0        1969  8.093333
# 1        1970  8.140000
# 2        1972  7.743750
# 3        1973  7.562500
# 4        1976  7.373684

# %%
sns.lineplot(data=a,x='date_aired',y='imdb')
plt.title("Average IMDB ratings over time")
plt.legend(['Avg Ratings'], loc='lower right')
plt.ylim(0, 10);

# %%
 df.drop('date_aired', axis=1).columns
# Out:
# Index(['index', 'series_name', 'network', 'season', 'title', 'imdb',
#        'engagement', 'run_time', 'format', 'monster_name', 'monster_gender',
#        'monster_type', 'monster_subtype', 'monster_species', 'monster_real',
#        'monster_amount', 'caught_fred', 'caught_daphnie', 'caught_velma',
#        'caught_shaggy', 'caught_scooby', 'captured_fred', 'captured_daphnie',
#        'captured_velma', 'captured_shaggy', 'captured_scooby', 'unmask_fred',
#        'unmask_daphnie', 'unmask_velma', 'unmask_shaggy', 'unmask_scooby',
#        'snack_fred', 'snack_daphnie', 'snack_velma', 'snack_shaggy',
#        'snack_scooby', 'unmask_other', 'caught_other', 'caught_not',
#        'trap_work_first', 'setting_terrain', 'setting_country_state',
#        'suspects_amount', 'non_suspect', 'arrested', 'culprit_name',
#        'culprit_gender', 'culprit_amount', 'motive', 'if_it_wasnt_for',
#        'and_that', 'door_gag', 'number_of_snacks', 'split_up',
# ...

# %%
def tiered_plots(df,title):
    # Initialize the figure style
    plt.style.use('seaborn-darkgrid')
    # create a color palette
    palette = plt.get_cmap('Set1')

    
    # multiple line plot
    num=0
    for column in df.drop('date_aired', axis=1):
        num+=1
    
        # Find the right spot on the plot
        plt.subplot(3,2, num)

        
        # Plot the lineplot
        sns.lineplot(data=df, x= 'date_aired', y = column, color=palette(num), linewidth=1.9, label=column)
    
        # Same limits for every chart
        #plt.xlim(0,30)
        #plt.ylim(0,22)
    
        # Not ticks everywhere
        if num in range(7) :
            plt.tick_params(labelbottom='off')
        if num not in [1,4,7] :
            plt.tick_params(labelleft='off')
    
        # Add title
        plt.title(column, loc='left', fontsize=12, fontweight=0, color=palette(num) )

    # general title
    plt.suptitle(title, fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
    
    # Axis titles
    # plt.text(0.5, 0.02, 'Time', ha='center', va='center')
    # plt.text(0.06, 0.5, 'Note', ha='center', va='center', rotation='vertical')

    # Show the graph
    plt.show()

# %%
'caught_fred', 'caught_daphnie',
       'caught_velma', 'caught_shaggy', 'caught_scooby', 'captured_fred',
       'captured_daphnie', 'captured_velma', 'captured_shaggy',
       'captured_scooby', 'unmask_fred', 'unmask_daphnie', 'unmask_velma',
       'unmask_shaggy', 'unmask_scooby', 'snack_fred', 'snack_daphnie',
       'snack_velma', 'snack_shaggy', 'snack_scooby'
# Out:
#   File "<ipython-input-20-19011ca946e1>", line 2
#     'caught_velma', 'caught_shaggy', 'caught_scooby', 'captured_fred',
#     ^
# IndentationError: unexpected indent

# %%
b=df.groupby(df.date_aired.dt.year)['caught_fred', 'caught_daphnie',
       'caught_velma', 'caught_shaggy', 'caught_scooby'].sum().reset_index().astype(float)
# Out:
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
b.head()
# Out:
#    date_aired  caught_fred  caught_daphnie  caught_velma  caught_shaggy  \
# 0      1969.0          5.0             0.0           0.0            5.0
# 1      1970.0          3.0             0.0           0.0            5.0
# 2      1972.0          6.0             0.0           0.0            4.0
# 3      1973.0          1.0             0.0           0.0            2.0
# 4      1976.0          6.0             1.0           1.0            5.0
#
#    caught_scooby
# 0            7.0
# 1            6.0
# 2            5.0
# 3            3.0
# 4            8.0

# %%
type(b.caught_fred[0])
# Out:
# int

# %%
tiered_plots(df=b,title="Who catches the spooks?")

# %%
df.if_it_wasnt_for.unique()
# Out:
# array([nan, 'these blasted kids', 'those meddling kids', 'you snoopers',
#        'that dumb dog', 'you people', 'brats', 'you meddling kids',
#        'these meddling kids', 'you and that dog coming along',
#        'pesky pair in the cow costume',
#        'these meddling laddies and lasses', 'nosy kids', 'those brats',
#        'you meddling young fools', 'you', 'you pesky kids',
#        'these pesky kids', 'those pesky kids',
#        'these nice, but trouble making kids', 'that super hero',
#        'Purvis and you kids', 'these kids', 'her friends',
#        'you nosey kids', 'those kids', 'that tunneling puppy',
#        'these two', 'you kids', 'meddl-', 'the damn cotton market',
#        'interloping adolescents', 'turistas', "ya'll meddling kids",
#        'you meddling mainlanders', 'you wonderful meddling kids',
#        'pestering kids', 'you meddling medieval kids',
#        'those meddling punks', 'you meddling foreign kids',
# ...

# %%
from wordcloud import WordCloud
wc = WordCloud()
wc.generate(df.if_it_wasnt_for)
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-f73f6478e98d> in <module>
#       1 from wordcloud import WordCloud
#       2 wc = WordCloud()
# ----> 3 wc.generate(df.if_it_wasnt_for)
#       4 plt.imshow(wc, interpolation="bilinear")
#       5 plt.axis('off')
#
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     629         self
#     630         """
# --> 631         return self.generate_from_text(text)
#     632
#     633     def _check_generated(self):
#
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     610         self
#     611         """
# --> 612         words = self.process_text(text)
#     613         self.generate_from_frequencies(words)
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
comment_words = ' '
stopwords = set(STOPWORDS) 
mask = np.array(Image.open('Scooby-Doo.png'))
# iterate through the csv file 
for val in df.if_it_wasnt_for: 

   # typecaste each val to string 
   val = str(val) 

   # split the value 
   tokens = val.split() 

# Converts each token into lowercase 
for i in range(len(tokens)): 
    tokens[i] = tokens[i].lower() 

for words in tokens: 
    comment_words = comment_words + words + ' '


wordcloud = WordCloud( 
            background_color ='white', 
            stopwords = stopwords, 
            min_font_size = 10,
            mask=mask,
            max_words=2000, max_font_size=256,
            random_state=42, width=mask.shape[1],
            height=mask.shape[0]).generate(comment_words) 

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-92edff348322> in <module>
#      36 plt.tight_layout(pad = 0)
#      37
# ---> 38 plt.imshow(wc, interpolation="bilinear")
#      39 plt.axis('off')
#      40 plt.show()
#
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2711         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2712         url=url, **({"data": data} if data is not None else {}),
# -> 2713         **kwargs)
#    2714     sci(__ret)
#    2715     return __ret
#
# d:\Users\DComputer\Desktop\learning\Streamlined EDA and ML\project_env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#              ...
# 598    you meddling kids
# 599                  NaN
# 600    you meddling kids
# 601    you meddling kids
# 602    you meddling kids
# Name: if_it_wasnt_for, Length: 603, dtype: object

# %%
o=df.if_it_wasnt_for

# %%
o.value_counts()
# Out:
# you meddling kids                                     65
# you pesky kids                                         9
# those meddling kids                                    4
# you meddling-                                          3
# you meddling kids who like an idiot I invited here     2
#                                                       ..
# you meddling young people                              1
# you meddling schoolmates of mine                       1
# these nice, but trouble making kids                    1
# Vincent Van Ghoul                                      1
# these meddling laddies and lasses                      1
# Name: if_it_wasnt_for, Length: 107, dtype: int64

# %%
o.drop()

# %%
# origninal
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
comment_words = ' '
stopwords = set(STOPWORDS) 

# iterate through the csv file 
for val in df.if_it_wasnt_for: 

   # typecaste each val to string 
   val = str(val) 

   # split the value 
   tokens = val.split() 

# Converts each token into lowercase 
for i in range(len(tokens)): 
    tokens[i] = tokens[i].lower() 

for words in tokens: 
    comment_words = comment_words + words + ' '


wordcloud = WordCloud(width = 800, height = 800, 
            background_color ='white', 
            stopwords = stopwords, 
            min_font_size = 10).generate(comment_words) 

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %%
from PIL import Image
import numpy as np

# %%
mask = np.array(Image.open('Scooby-Doo.png'))
wc = WordCloud(stopwords=STOPWORDS, font_path=font_path,
               mask=mask, background_color="white",
               max_words=2000, max_font_size=256,
               random_state=42, width=mask.shape[1],
               height=mask.shape[0])
wc.generate(comment_words)
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
mask = np.array(Image.open('Scooby-Doo.png'))
alice_wc = WordCloud(background_color='white', max_words=2000, mask=mask, stopwords=stopwords)
# generate the word cloud
alice_wc.generate(comment_words)
# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
